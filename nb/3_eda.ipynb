# %% [markdown]
# ### impor libarys

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### load dataset

# %%
data_path = Path("../data/Palo Alto Networks.csv")
df1 = pd.read_csv(data_path)

# %%
df = df1

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# ### dataset shape

# %%
print(f"dataset shape",df.shape)
print(f"number of row",df.shape[0])
print(f"number of columns",df.shape[1])
# Out:
# dataset shape (1470, 31)
# number of row 1470
# number of columns 31

# %% [markdown]
# ### columns names

# %%
print("Dataset Columns:\n")

for i, col in enumerate(df.columns, start=1):
    print(f"{i}. {col}")
# Out:
# Dataset Columns:
#
# 1. Age
# 2. Attrition
# 3. BusinessTravel
# 4. DailyRate
# 5. Department
# 6. DistanceFromHome
# 7. Education
# 8. EducationField
# 9. EnvironmentSatisfaction
# 10. Gender
# 11. HourlyRate
# 12. JobInvolvement
# 13. JobLevel
# 14. JobRole
# 15. JobSatisfaction
# 16. MaritalStatus
# 17. MonthlyIncome
# 18. MonthlyRate
# 19. NumCompaniesWorked
# 20. OverTime
# 21. PercentSalaryHike
# 22. PerformanceRating
# 23. RelationshipSatisfaction
# 24. StockOptionLevel
# 25. TotalWorkingYears
# 26. TrainingTimesLastYear
# 27. WorkLifeBalance
# 28. YearsAtCompany
# 29. YearsInCurrentRole
# 30. YearsSinceLastPromotion
# 31. YearsWithCurrManager

# %% [markdown]
# ### columns datatypes

# %%
dtype_summary = pd.DataFrame({
    'Column': df.columns,
    'Data_Type': df.dtypes.values
})

display(dtype_summary)
# Out:
#                       Column Data_Type
# 0                        Age     int64
# 1                  Attrition     int64
# 2             BusinessTravel    object
# 3                  DailyRate     int64
# 4                 Department    object
# 5           DistanceFromHome     int64
# 6                  Education     int64
# 7             EducationField    object
# 8    EnvironmentSatisfaction     int64
# 9                     Gender    object
# 10                HourlyRate     int64
# 11            JobInvolvement     int64
# 12                  JobLevel     int64
# 13                   JobRole    object
# 14           JobSatisfaction     int64
# 15             MaritalStatus    object
# 16             MonthlyIncome     int64
# 17               MonthlyRate     int64
# 18        NumCompaniesWorked     int64
# 19                  OverTime    object
# 20         PercentSalaryHike     int64
# 21         PerformanceRating     int64
# 22  RelationshipSatisfaction     int64
# ...

# %% [markdown]
# ### info about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %% [markdown]
# ### first 5 rcords

# %%
display(df.head())
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# ### Numerical Statistical Summary

# %%
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# ...

# %% [markdown]
# ### Categorical Summary

# %%
display(df.describe(include='object'))
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            1470                    1470           1470   1470
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             1043                     961            606    882
#
#                 JobRole MaritalStatus OverTime
# count              1470          1470     1470
# unique                9             3        2
# top     Sales Executive       Married       No
# freq                326           673     1054

# %%
# ==========================================
# DAY 3 - DATASET OVERVIEW SUMMARY
# ==========================================

dataset_overview = pd.DataFrame({
    'Metric': [
        'Number of Records',
        'Number of Columns',
        'Missing Values',
        'Duplicate Rows',
        'Numerical Columns',
        'Categorical Columns'
    ],
    
    'Value': [
        df.shape[0],
        df.shape[1],
        df.isnull().sum().sum(),
        df.duplicated().sum(),
        df.select_dtypes(include=['int64', 'float64']).shape[1],
        df.select_dtypes(include=['object']).shape[1]
    ]
})

display(dataset_overview)
# Out:
#                 Metric  Value
# 0    Number of Records   1470
# 1    Number of Columns     31
# 2       Missing Values      0
# 3       Duplicate Rows      0
# 4    Numerical Columns     24
# 5  Categorical Columns      7

# %% [markdown]
# ### age analysis

# %%
df['Age'].describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.hist(
    df['Age'],
    bins=10,
    edgecolor='black'
)

plt.title('Employee Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of Employees')

plt.tight_layout()

plt.show()

# %%
age_bins = [17, 25, 35, 45, 55, 65]

age_labels = [
    '18-25',
    '26-35',
    '36-45',
    '46-55',
    '56-65'
]

df['AgeGroup'] = pd.cut(
    df['Age'],
    bins=age_bins,
    labels=age_labels
)

age_group_summary = (
    df['AgeGroup']
    .value_counts()
    .sort_index()
    .reset_index()
)

age_group_summary.columns = [
    'Age_Group',
    'Employee_Count'
]

age_group_summary['Percentage'] = (
    age_group_summary['Employee_Count']
    / age_group_summary['Employee_Count'].sum()
    * 100
).round(2)

display(age_group_summary)
# Out:
#   Age_Group  Employee_Count  Percentage
# 0     18-25             123        8.37
# 1     26-35             606       41.22
# 2     36-45             468       31.84
# 3     46-55             226       15.37
# 4     56-65              47        3.20

# %% [markdown]
# ### department analysis

# %%
department_summary = (
    df['Department']
    .value_counts()
    .reset_index()
)

department_summary.columns = [
    'Department',
    'Employee_Count'
]

display(department_summary)
# Out:
#                Department  Employee_Count
# 0  Research & Development             961
# 1                   Sales             446
# 2         Human Resources              63

# %%
department_summary['Percentage'] = (
    department_summary['Employee_Count']
    / department_summary['Employee_Count'].sum()
    * 100
).round(2)

display(department_summary)
# Out:
#                Department  Employee_Count  Percentage
# 0  Research & Development             961       65.37
# 1                   Sales             446       30.34
# 2         Human Resources              63        4.29

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.bar(
    department_summary['Department'],
    department_summary['Employee_Count'],
    edgecolor='black'
)

plt.title('Employee Distribution by Department')
plt.xlabel('Department')
plt.ylabel('Number of Employees')

plt.xticks(rotation=15)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### jobrole analysis

# %%
job_role_summary = (
    df['JobRole']
    .value_counts()
    .reset_index()
)

job_role_summary.columns = [
    'Job_Role',
    'Employee_Count'
]

display(job_role_summary)
# Out:
#                     Job_Role  Employee_Count
# 0            Sales Executive             326
# 1         Research Scientist             292
# 2      Laboratory Technician             259
# 3     Manufacturing Director             145
# 4  Healthcare Representative             131
# 5                    Manager             102
# 6       Sales Representative              83
# 7          Research Director              80
# 8            Human Resources              52

# %%
job_role_summary['Percentage'] = (
    job_role_summary['Employee_Count']
    / job_role_summary['Employee_Count'].sum()
    * 100
).round(2)

display(job_role_summary)
# Out:
#                     Job_Role  Employee_Count  Percentage
# 0            Sales Executive             326       22.18
# 1         Research Scientist             292       19.86
# 2      Laboratory Technician             259       17.62
# 3     Manufacturing Director             145        9.86
# 4  Healthcare Representative             131        8.91
# 5                    Manager             102        6.94
# 6       Sales Representative              83        5.65
# 7          Research Director              80        5.44
# 8            Human Resources              52        3.54

# %%
import matplotlib.pyplot as plt

# Sort data for better visualization
job_role_chart = job_role_summary.sort_values(
    by='Employee_Count',
    ascending=True
)

plt.figure(figsize=(10, 6))

plt.barh(
    job_role_chart['Job_Role'],
    job_role_chart['Employee_Count'],
    edgecolor='black'
)

plt.title('Employee Distribution by Job Role')
plt.xlabel('Number of Employees')
plt.ylabel('Job Role')

plt.tight_layout()

plt.show()

# %%
largest_job_role = job_role_summary.loc[
    job_role_summary['Employee_Count'].idxmax()
]

smallest_job_role = job_role_summary.loc[
    job_role_summary['Employee_Count'].idxmin()
]

print("Largest Job Role:")
print(largest_job_role)

print("\nSmallest Job Role:")
print(smallest_job_role)
# Out:
# Largest Job Role:
# Job_Role          Sales Executive
# Employee_Count                326
# Percentage                  22.18
# Name: 0, dtype: object
#
# Smallest Job Role:
# Job_Role          Human Resources
# Employee_Count                 52
# Percentage                   3.54
# Name: 8, dtype: object

# %% [markdown]
# ### Job Role Analysis Conclusion
#
# ### The Job Role analysis shows the distribution of employees across different organizational roles. The largest role represents the highest concentration of employees, while the smallest role has limited representation. Understanding this distribution provides a baseline for later analysis of attrition, career progression, and workforce planning by job role.

# %% [markdown]
# ### job level anaysis

# %%
job_level_summary = (
    df['JobLevel']
    .value_counts()
    .sort_index()
    .reset_index()
)

job_level_summary.columns = [
    'Job_Level',
    'Employee_Count'
]

# Calculate percentage
job_level_summary['Percentage'] = (
    job_level_summary['Employee_Count']
    / job_level_summary['Employee_Count'].sum()
    * 100
).round(2)

display(job_level_summary)
# Out:
#    Job_Level  Employee_Count  Percentage
# 0          1             543       36.94
# 1          2             534       36.33
# 2          3             218       14.83
# 3          4             106        7.21
# 4          5              69        4.69

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.bar(
    job_level_summary['Job_Level'].astype(str),
    job_level_summary['Employee_Count'],
    edgecolor='black'
)

plt.title('Employee Distribution by Job Level')
plt.xlabel('Job Level')
plt.ylabel('Number of Employees')

plt.tight_layout()


plt.show()

# %% [markdown]
# ### Career Variables Analysis

# %%
career_columns = [
    'TotalWorkingYears',
    'YearsAtCompany',
    'YearsInCurrentRole',
    'YearsSinceLastPromotion',
    'YearsWithCurrManager'
]

career_summary = pd.DataFrame({
    'Variable': career_columns,
    
    'Count': [
        df[col].count() for col in career_columns
    ],
    
    'Mean': [
        round(df[col].mean(), 2) for col in career_columns
    ],
    
    'Median': [
        df[col].median() for col in career_columns
    ],
    
    'Minimum': [
        df[col].min() for col in career_columns
    ],
    
    'Maximum': [
        df[col].max() for col in career_columns
    ],
    
    'Standard_Deviation': [
        round(df[col].std(), 2) for col in career_columns
    ]
})

display(career_summary)
# Out:
#                   Variable  Count   Mean  Median  Minimum  Maximum  \
# 0        TotalWorkingYears   1470  11.28    10.0        0       40
# 1           YearsAtCompany   1470   7.01     5.0        0       40
# 2       YearsInCurrentRole   1470   4.23     3.0        0       18
# 3  YearsSinceLastPromotion   1470   2.19     1.0        0       15
# 4     YearsWithCurrManager   1470   4.12     3.0        0       17
#
#    Standard_Deviation
# 0                7.78
# 1                6.13
# 2                3.62
# 3                3.22
# 4                3.57

# %%
reliable_career_columns = [
    'TotalWorkingYears',
    'YearsInCurrentRole',
    'YearsSinceLastPromotion',
    'YearsWithCurrManager'
]

for col in reliable_career_columns:
    
    plt.figure(figsize=(10, 6))
    
    plt.hist(
        df[col],
        bins=10,
        edgecolor='black'
    )
    
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Number of Employees')
    
    plt.tight_layout()

    plt.show()

# %%
experience_bins = [-1, 5, 10, 20, float('inf')]

experience_labels = [
    '0-5 Years',
    '6-10 Years',
    '11-20 Years',
    '20+ Years'
]

df['ExperienceGroup'] = pd.cut(
    df['TotalWorkingYears'],
    bins=experience_bins,
    labels=experience_labels
)

experience_summary = (
    df['ExperienceGroup']
    .value_counts()
    .sort_index()
    .reset_index()
)

experience_summary.columns = [
    'Experience_Group',
    'Employee_Count'
]

experience_summary['Percentage'] = (
    experience_summary['Employee_Count']
    / experience_summary['Employee_Count'].sum()
    * 100
).round(2)

display(experience_summary)
# Out:
#   Experience_Group  Employee_Count  Percentage
# 0        0-5 Years             316       21.50
# 1       6-10 Years             607       41.29
# 2      11-20 Years             340       23.13
# 3        20+ Years             207       14.08

# %%
promotion_bins = [-1, 1, 3, 5, float('inf')]

promotion_labels = [
    '0-1 Years',
    '2-3 Years',
    '4-5 Years',
    '6+ Years'
]

df['PromotionGapGroup'] = pd.cut(
    df['YearsSinceLastPromotion'],
    bins=promotion_bins,
    labels=promotion_labels
)

promotion_summary = (
    df['PromotionGapGroup']
    .value_counts()
    .sort_index()
    .reset_index()
)

promotion_summary.columns = [
    'Promotion_Gap_Group',
    'Employee_Count'
]

promotion_summary['Percentage'] = (
    promotion_summary['Employee_Count']
    / promotion_summary['Employee_Count'].sum()
    * 100
).round(2)

display(promotion_summary)
# Out:
#   Promotion_Gap_Group  Employee_Count  Percentage
# 0           0-1 Years             938       63.81
# 1           2-3 Years             211       14.35
# 2           4-5 Years             106        7.21
# 3            6+ Years             215       14.63

# %%
manager_bins = [-1, 2, 5, 10, float('inf')]

manager_labels = [
    '0-2 Years',
    '3-5 Years',
    '6-10 Years',
    '10+ Years'
]

df['ManagerDurationGroup'] = pd.cut(
    df['YearsWithCurrManager'],
    bins=manager_bins,
    labels=manager_labels
)

manager_duration_summary = (
    df['ManagerDurationGroup']
    .value_counts()
    .sort_index()
    .reset_index()
)

manager_duration_summary.columns = [
    'Manager_Duration_Group',
    'Employee_Count'
]

manager_duration_summary['Percentage'] = (
    manager_duration_summary['Employee_Count']
    / manager_duration_summary['Employee_Count'].sum()
    * 100
).round(2)

display(manager_duration_summary)
# Out:
#   Manager_Duration_Group  Employee_Count  Percentage
# 0              0-2 Years             683       46.46
# 1              3-5 Years             271       18.44
# 2             6-10 Years             443       30.14
# 3              10+ Years              73        4.97

# %% [markdown]
# ### Training Analysis

# %%
training_summary = pd.DataFrame({
    'Metric': [
        'Count',
        'Mean',
        'Median',
        'Minimum',
        'Maximum',
        'Standard Deviation'
    ],
    
    'Value': [
        df['TrainingTimesLastYear'].count(),
        round(df['TrainingTimesLastYear'].mean(), 2),
        df['TrainingTimesLastYear'].median(),
        df['TrainingTimesLastYear'].min(),
        df['TrainingTimesLastYear'].max(),
        round(df['TrainingTimesLastYear'].std(), 2)
    ]
})

display(training_summary)
# Out:
#                Metric    Value
# 0               Count  1470.00
# 1                Mean     2.80
# 2              Median     3.00
# 3             Minimum     0.00
# 4             Maximum     6.00
# 5  Standard Deviation     1.29

# %%
training_frequency = (
    df['TrainingTimesLastYear']
    .value_counts()
    .sort_index()
    .reset_index()
)

training_frequency.columns = [
    'Training_Times_Last_Year',
    'Employee_Count'
]

training_frequency['Percentage'] = (
    training_frequency['Employee_Count']
    / training_frequency['Employee_Count'].sum()
    * 100
).round(2)

display(training_frequency)
# Out:
#    Training_Times_Last_Year  Employee_Count  Percentage
# 0                         0              54        3.67
# 1                         1              71        4.83
# 2                         2             547       37.21
# 3                         3             491       33.40
# 4                         4             123        8.37
# 5                         5             119        8.10
# 6                         6              65        4.42

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.bar(
    training_frequency['Training_Times_Last_Year'].astype(str),
    training_frequency['Employee_Count'],
    edgecolor='black'
)

plt.title('Employee Training Frequency in the Last Year')
plt.xlabel('Number of Training Sessions')
plt.ylabel('Number of Employees')

plt.tight_layout()

plt.show()

# %%
training_bins = [-1, 0, 2, 4, float('inf')]

training_labels = [
    'No Training',
    'Low Training (1-2)',
    'Moderate Training (3-4)',
    'High Training (5+)'
]

df['TrainingGroup'] = pd.cut(
    df['TrainingTimesLastYear'],
    bins=training_bins,
    labels=training_labels
)

training_group_summary = (
    df['TrainingGroup']
    .value_counts()
    .sort_index()
    .reset_index()
)

training_group_summary.columns = [
    'Training_Group',
    'Employee_Count'
]

training_group_summary['Percentage'] = (
    training_group_summary['Employee_Count']
    / training_group_summary['Employee_Count'].sum()
    * 100
).round(2)

display(training_group_summary)
# Out:
#             Training_Group  Employee_Count  Percentage
# 0              No Training              54        3.67
# 1       Low Training (1-2)             618       42.04
# 2  Moderate Training (3-4)             614       41.77
# 3       High Training (5+)             184       12.52

# %% [markdown]
# ### Attrition analysis

# %%
total_employees = len(df)

employees_left = df['Attrition'].sum()

employees_stayed = total_employees - employees_left

attrition_rate = round(
    employees_left / total_employees * 100,
    2
)

overall_attrition_summary = pd.DataFrame({
    'Metric': [
        'Total Employees',
        'Employees Stayed',
        'Employees Left',
        'Attrition Rate (%)'
    ],

    'Value': [
        total_employees,
        employees_stayed,
        employees_left,
        attrition_rate
    ]
})

display(overall_attrition_summary)
# Out:
#                Metric    Value
# 0     Total Employees  1470.00
# 1    Employees Stayed  1233.00
# 2      Employees Left   237.00
# 3  Attrition Rate (%)    16.12

# %%
attrition_counts = (
    df['Attrition']
    .value_counts()
    .sort_index()
)

attrition_labels = ['Stayed', 'Left']

plt.figure(figsize=(7, 5))

plt.bar(
    attrition_labels,
    attrition_counts.values,
    edgecolor='black'
)

plt.title('Overall Employee Attrition')
plt.xlabel('Employee Status')
plt.ylabel('Number of Employees')

plt.tight_layout()

plt.show()

# %%
department_attrition = (
    df.groupby('Department')
    .agg(
        Total_Employees=('Attrition', 'count'),
        Employees_Left=('Attrition', 'sum')
    )
    .reset_index()
)

department_attrition['Attrition_Rate (%)'] = (
    department_attrition['Employees_Left']
    / department_attrition['Total_Employees']
    * 100
).round(2)

department_attrition = department_attrition.sort_values(
    by='Attrition_Rate (%)',
    ascending=False
)

display(department_attrition)
# Out:
#                Department  Total_Employees  Employees_Left  Attrition_Rate (%)
# 2                   Sales              446              92               20.63
# 0         Human Resources               63              12               19.05
# 1  Research & Development              961             133               13.84

# %%
department_chart = department_attrition.sort_values(
    by='Attrition_Rate (%)',
    ascending=True
)

plt.figure(figsize=(10, 6))

plt.barh(
    department_chart['Department'],
    department_chart['Attrition_Rate (%)'],
    edgecolor='black'
)

plt.title('Attrition Rate by Department')
plt.xlabel('Attrition Rate (%)')
plt.ylabel('Department')

plt.tight_layout()

plt.show()

# %%
job_role_attrition = (
    df.groupby('JobRole')
    .agg(
        Total_Employees=('Attrition', 'count'),
        Employees_Left=('Attrition', 'sum')
    )
    .reset_index()
)

job_role_attrition['Attrition_Rate (%)'] = (
    job_role_attrition['Employees_Left']
    / job_role_attrition['Total_Employees']
    * 100
).round(2)

job_role_attrition = job_role_attrition.sort_values(
    by='Attrition_Rate (%)',
    ascending=False
)

display(job_role_attrition)
# Out:
#                      JobRole  Total_Employees  Employees_Left  \
# 8       Sales Representative               83              33
# 2      Laboratory Technician              259              62
# 1            Human Resources               52              12
# 7            Sales Executive              326              57
# 6         Research Scientist              292              47
# 4     Manufacturing Director              145              10
# 0  Healthcare Representative              131               9
# 3                    Manager              102               5
# 5          Research Director               80               2
#
#    Attrition_Rate (%)
# 8               39.76
# 2               23.94
# 1               23.08
# 7               17.48
# 6               16.10
# 4                6.90
# 0                6.87
# 3                4.90
# 5                2.50

# %%
job_role_chart = job_role_attrition.sort_values(
    by='Attrition_Rate (%)',
    ascending=True
)

plt.figure(figsize=(10, 6))

plt.barh(
    job_role_chart['JobRole'],
    job_role_chart['Attrition_Rate (%)'],
    edgecolor='black'
)

plt.title('Attrition Rate by Job Role')
plt.xlabel('Attrition Rate (%)')
plt.ylabel('Job Role')

plt.tight_layout()

plt.show()

# %%
job_level_attrition = (
    df.groupby('JobLevel')
    .agg(
        Total_Employees=('Attrition', 'count'),
        Employees_Left=('Attrition', 'sum')
    )
    .reset_index()
)

job_level_attrition['Attrition_Rate (%)'] = (
    job_level_attrition['Employees_Left']
    / job_level_attrition['Total_Employees']
    * 100
).round(2)

job_level_attrition = job_level_attrition.sort_values(
    by='JobLevel'
)

display(job_level_attrition)
# Out:
#    JobLevel  Total_Employees  Employees_Left  Attrition_Rate (%)
# 0         1              543             143               26.34
# 1         2              534              52                9.74
# 2         3              218              32               14.68
# 3         4              106               5                4.72
# 4         5               69               5                7.25

# %%
plt.figure(figsize=(8, 5))

plt.bar(
    job_level_attrition['JobLevel'].astype(str),
    job_level_attrition['Attrition_Rate (%)'],
    edgecolor='black'
)

plt.title('Attrition Rate by Job Level')
plt.xlabel('Job Level')
plt.ylabel('Attrition Rate (%)')

plt.tight_layout()

plt.show()

# %%
highest_attrition_job_level = job_level_attrition.loc[
    job_level_attrition['Attrition_Rate (%)'].idxmax()
]

print(highest_attrition_job_level)
# Out:
# JobLevel                1.00
# Total_Employees       543.00
# Employees_Left        143.00
# Attrition_Rate (%)     26.34
# Name: 0, dtype: float64

# %% [markdown]
# ### Career Progression Analysis

# %%
promotion_gap_summary = (
    df.groupby('PromotionGapGroup', observed=False)
    .size()
    .reset_index(name='Employee_Count')
)

promotion_gap_summary['Percentage'] = (
    promotion_gap_summary['Employee_Count']
    / promotion_gap_summary['Employee_Count'].sum()
    * 100
).round(2)

display(promotion_gap_summary)
# Out:
#   PromotionGapGroup  Employee_Count  Percentage
# 0         0-1 Years             938       63.81
# 1         2-3 Years             211       14.35
# 2         4-5 Years             106        7.21
# 3          6+ Years             215       14.63

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    promotion_gap_summary['PromotionGapGroup'].astype(str),
    promotion_gap_summary['Employee_Count'],
    edgecolor='black'
)

plt.title('Employee Promotion Gap Distribution')
plt.xlabel('Years Since Last Promotion')
plt.ylabel('Number of Employees')

plt.tight_layout()

plt.show()

# %%
df['RoleDurationGroup'] = pd.cut(
    df['YearsInCurrentRole'],
    bins=[-1, 2, 5, 10, float('inf')],
    labels=['0-2 Years', '3-5 Years', '6-10 Years', '10+ Years']
)

# %% [markdown]
# ### Promotion Gap vs Attrition

# %%
role_stagnation_summary = (
    df.groupby('RoleDurationGroup', observed=False)
    .size()
    .reset_index(name='Employee_Count')
)

role_stagnation_summary['Percentage'] = (
    role_stagnation_summary['Employee_Count']
    / role_stagnation_summary['Employee_Count'].sum()
    * 100
).round(2)

display(role_stagnation_summary)
# Out:
#   RoleDurationGroup  Employee_Count  Percentage
# 0         0-2 Years             673       45.78
# 1         3-5 Years             275       18.71
# 2        6-10 Years             444       30.20
# 3         10+ Years              78        5.31

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    role_stagnation_summary['RoleDurationGroup'].astype(str),
    role_stagnation_summary['Employee_Count'],
    edgecolor='black'
)

plt.title('Employee Role Duration Distribution')
plt.xlabel('Years in Current Role')
plt.ylabel('Number of Employees')

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Promotion Gap vs Attrition

# %%
promotion_attrition = (
    df.groupby('PromotionGapGroup', observed=False)
    .agg(
        Total_Employees=('Attrition', 'count'),
        Employees_Left=('Attrition', 'sum')
    )
    .reset_index()
)

promotion_attrition['Attrition_Rate (%)'] = (
    promotion_attrition['Employees_Left']
    / promotion_attrition['Total_Employees']
    * 100
).round(2)

display(promotion_attrition)
# Out:
#   PromotionGapGroup  Total_Employees  Employees_Left  Attrition_Rate (%)
# 0         0-1 Years              938             159               16.95
# 1         2-3 Years              211              36               17.06
# 2         4-5 Years              106               7                6.60
# 3          6+ Years              215              35               16.28

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    promotion_attrition['PromotionGapGroup'].astype(str),
    promotion_attrition['Attrition_Rate (%)'],
    edgecolor='black'
)

plt.title('Promotion Gap vs Attrition Rate')
plt.xlabel('Years Since Last Promotion')
plt.ylabel('Attrition Rate (%)')

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Role Duration vs Attrition

# %%
role_duration_attrition = (
    df.groupby('RoleDurationGroup', observed=False)
    .agg(
        Total_Employees=('Attrition', 'count'),
        Employees_Left=('Attrition', 'sum')
    )
    .reset_index()
)

role_duration_attrition['Attrition_Rate (%)'] = (
    role_duration_attrition['Employees_Left']
    / role_duration_attrition['Total_Employees']
    * 100
).round(2)

display(role_duration_attrition)
# Out:
#   RoleDurationGroup  Total_Employees  Employees_Left  Attrition_Rate (%)
# 0         0-2 Years              673             152               22.59
# 1         3-5 Years              275              32               11.64
# 2        6-10 Years              444              48               10.81
# 3         10+ Years               78               5                6.41

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    role_duration_attrition['RoleDurationGroup'].astype(str),
    role_duration_attrition['Attrition_Rate (%)'],
    edgecolor='black'
)

plt.title('Role Duration vs Attrition Rate')
plt.xlabel('Years in Current Role')
plt.ylabel('Attrition Rate (%)')

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Training vs Career Progression

# %%
training_promotion = (
    df.groupby('PromotionGapGroup', observed=False)
    .agg(
        Employee_Count=('TrainingTimesLastYear', 'count'),
        Average_Training=('TrainingTimesLastYear', 'mean'),
        Median_Training=('TrainingTimesLastYear', 'median')
    )
    .reset_index()
)

training_promotion['Average_Training'] = (
    training_promotion['Average_Training']
    .round(2)
)

display(training_promotion)
# Out:
#   PromotionGapGroup  Employee_Count  Average_Training  Median_Training
# 0         0-1 Years             938              2.79              3.0
# 1         2-3 Years             211              2.78              3.0
# 2         4-5 Years             106              2.96              3.0
# 3          6+ Years             215              2.78              3.0

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    training_promotion['PromotionGapGroup'].astype(str),
    training_promotion['Average_Training'],
    edgecolor='black'
)

plt.title('Average Training Frequency by Promotion Gap')
plt.xlabel('Promotion Gap')
plt.ylabel('Average Training Sessions')

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Training vs Role Duration

# %%
training_role_duration = (
    df.groupby('RoleDurationGroup', observed=False)
    .agg(
        Employee_Count=('TrainingTimesLastYear', 'count'),
        Average_Training=('TrainingTimesLastYear', 'mean'),
        Median_Training=('TrainingTimesLastYear', 'median')
    )
    .reset_index()
)

training_role_duration['Average_Training'] = (
    training_role_duration['Average_Training']
    .round(2)
)

display(training_role_duration)
# Out:
#   RoleDurationGroup  Employee_Count  Average_Training  Median_Training
# 0         0-2 Years             673              2.77              3.0
# 1         3-5 Years             275              2.87              3.0
# 2        6-10 Years             444              2.84              3.0
# 3         10+ Years              78              2.63              3.0

# %%
plt.figure(figsize=(10, 6))

plt.bar(
    training_role_duration['RoleDurationGroup'].astype(str),
    training_role_duration['Average_Training'],
    edgecolor='black'
)

plt.title('Average Training Frequency by Role Duration')
plt.xlabel('Years in Current Role')
plt.ylabel('Average Training Sessions')

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Department-Level Analysis

# %%
department_summary = (
    df.groupby('Department')
    .agg(
        Total_Employees=('Attrition', 'count'),
        Employees_Left=('Attrition', 'sum'),
        
        Average_Monthly_Income=('MonthlyIncome', 'mean'),
        
        Average_Job_Satisfaction=('JobSatisfaction', 'mean'),
        Average_WorkLife_Balance=('WorkLifeBalance', 'mean'),
        
        Average_Training=('TrainingTimesLastYear', 'mean'),
        
        Average_Years_Since_Last_Promotion=(
            'YearsSinceLastPromotion',
            'mean'
        ),
        
        Average_Years_In_Current_Role=(
            'YearsInCurrentRole',
            'mean'
        )
    )
    .reset_index()
)

# %%
department_summary['Attrition_Rate (%)'] = (
    department_summary['Employees_Left']
    / department_summary['Total_Employees']
    * 100
).round(2)

# %%
numeric_columns = [
    'Average_Monthly_Income',
    'Average_Job_Satisfaction',
    'Average_WorkLife_Balance',
    'Average_Training',
    'Average_Years_Since_Last_Promotion',
    'Average_Years_In_Current_Role'
]

department_summary[numeric_columns] = (
    department_summary[numeric_columns].round(2)
)

display(department_summary)
# Out:
#                Department  Total_Employees  Employees_Left  \
# 0         Human Resources               63              12
# 1  Research & Development              961             133
# 2                   Sales              446              92
#
#    Average_Monthly_Income  Average_Job_Satisfaction  Average_WorkLife_Balance  \
# 0                 6654.51                      2.60                      2.92
# 1                 6281.25                      2.73                      2.73
# 2                 6959.17                      2.75                      2.82
#
#    Average_Training  Average_Years_Since_Last_Promotion  \
# 0              2.56                                1.78
# 1              2.79                                2.14
# 2              2.85                                2.35
#
#    Average_Years_In_Current_Role  Attrition_Rate (%)
# 0                           3.54               19.05
# 1                           4.16               13.84
# ...

# %% [markdown]
# ### Average Monthly Income by Department

# %%
plt.figure(figsize=(9, 5))

plt.bar(
    department_summary['Department'],
    department_summary['Average_Monthly_Income'],
    edgecolor='black'
)

plt.title('Average Monthly Income by Department')
plt.xlabel('Department')
plt.ylabel('Average Monthly Income')

plt.xticks(rotation=15)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Average Job Satisfaction by Department

# %%
plt.figure(figsize=(9, 5))

plt.bar(
    department_summary['Department'],
    department_summary['Average_Job_Satisfaction'],
    edgecolor='black'
)

plt.title('Average Job Satisfaction by Department')
plt.xlabel('Department')
plt.ylabel('Average Job Satisfaction')

plt.xticks(rotation=15)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Average Work-Life Balance by Department

# %%
plt.figure(figsize=(9, 5))

plt.bar(
    department_summary['Department'],
    department_summary['Average_WorkLife_Balance'],
    edgecolor='black'
)

plt.title('Average Work-Life Balance by Department')
plt.xlabel('Department')
plt.ylabel('Average Work-Life Balance')

plt.xticks(rotation=15)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Career Progression by Department

# %%
x = np.arange(len(department_summary))

width = 0.35

plt.figure(figsize=(10, 6))

plt.bar(
    x - width / 2,
    department_summary['Average_Years_Since_Last_Promotion'],
    width,
    label='Years Since Last Promotion',
    edgecolor='black'
)

plt.bar(
    x + width / 2,
    department_summary['Average_Years_In_Current_Role'],
    width,
    label='Years In Current Role',
    edgecolor='black'
)

plt.title('Career Progression Indicators by Department')

plt.xlabel('Department')
plt.ylabel('Average Years')

plt.xticks(
    x,
    department_summary['Department'],
    rotation=15
)

plt.legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
numerical_columns = df.select_dtypes(
    include=['int64', 'float64']
).columns

print(numerical_columns.tolist())
# Out:
# ['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
correlation_matrix = (
    df[numerical_columns]
    .corr()
    .round(2)
)

display(correlation_matrix)
# Out:
#                            Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.00      -0.16       0.01             -0.00
# Attrition                -0.16       1.00      -0.06              0.08
# DailyRate                 0.01      -0.06       1.00             -0.00
# DistanceFromHome         -0.00       0.08      -0.00              1.00
# Education                 0.21      -0.03      -0.02              0.02
# EnvironmentSatisfaction   0.01      -0.10       0.02             -0.02
# HourlyRate                0.02      -0.01       0.02              0.03
# JobInvolvement            0.03      -0.13       0.05              0.01
# JobLevel                  0.51      -0.17       0.00              0.01
# JobSatisfaction          -0.00      -0.10       0.03             -0.00
# MonthlyIncome             0.50      -0.16       0.01             -0.02
# MonthlyRate               0.03       0.02      -0.03              0.03
# ...

# %% [markdown]
# ### Create Correlation Heatmap

# %%
plt.figure(figsize=(18, 14))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0,
    linewidths=0.5
)

plt.title('Correlation Matrix of Numerical Variables')

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Correlation with Attrition

# %%
attrition_correlation = (
    correlation_matrix['Attrition']
    .drop('Attrition')
    .sort_values()
)

display(attrition_correlation)
# Out:
# TotalWorkingYears          -0.17
# JobLevel                   -0.17
# Age                        -0.16
# YearsInCurrentRole         -0.16
# MonthlyIncome              -0.16
# YearsWithCurrManager       -0.16
# StockOptionLevel           -0.14
# JobInvolvement             -0.13
# YearsAtCompany             -0.13
# EnvironmentSatisfaction    -0.10
# JobSatisfaction            -0.10
# DailyRate                  -0.06
# WorkLifeBalance            -0.06
# TrainingTimesLastYear      -0.06
# RelationshipSatisfaction   -0.05
# YearsSinceLastPromotion    -0.03
# Education                  -0.03
# PercentSalaryHike          -0.01
# HourlyRate                 -0.01
# PerformanceRating           0.00
# MonthlyRate                 0.02
# NumCompaniesWorked          0.04
# DistanceFromHome            0.08
# Name: Attrition, dtype: float64

# %% [markdown]
# ### Create a clean Attrition Correlation Table

# %%
attrition_correlation_table = (
    attrition_correlation
    .reset_index()
)

attrition_correlation_table.columns = [
    'Variable',
    'Correlation_With_Attrition'
]

attrition_correlation_table['Absolute_Correlation'] = (
    attrition_correlation_table[
        'Correlation_With_Attrition'
    ].abs()
)

attrition_correlation_table = (
    attrition_correlation_table
    .sort_values(
        by='Absolute_Correlation',
        ascending=False
    )
)

display(attrition_correlation_table)
# Out:
#                     Variable  Correlation_With_Attrition  Absolute_Correlation
# 0          TotalWorkingYears                       -0.17                  0.17
# 1                   JobLevel                       -0.17                  0.17
# 2                        Age                       -0.16                  0.16
# 3         YearsInCurrentRole                       -0.16                  0.16
# 4              MonthlyIncome                       -0.16                  0.16
# 5       YearsWithCurrManager                       -0.16                  0.16
# 6           StockOptionLevel                       -0.14                  0.14
# 7             JobInvolvement                       -0.13                  0.13
# 8             YearsAtCompany                       -0.13                  0.13
# 9    EnvironmentSatisfaction                       -0.10                  0.10
# 10           JobSatisfaction                       -0.10                  0.10
# ...

# %% [markdown]
# ### Visualize Correlation with Attrition

# %%
attrition_chart = attrition_correlation.sort_values()

plt.figure(figsize=(10, 8))

plt.barh(
    attrition_chart.index,
    attrition_chart.values,
    edgecolor='black'
)

plt.axvline(
    x=0,
    linewidth=1
)

plt.title('Correlation of Numerical Variables with Attrition')
plt.xlabel('Correlation with Attrition')
plt.ylabel('Variables')

plt.tight_layout()

plt.show()

# %% [markdown]
# ### strongest relationships

# %%
correlation_pairs = (
    correlation_matrix
    .where(
        np.triu(
            np.ones(correlation_matrix.shape),
            k=1
        ).astype(bool)
    )
    .stack()
    .reset_index()
)

correlation_pairs.columns = [
    'Variable_1',
    'Variable_2',
    'Correlation'
]

# %%
correlation_pairs['Absolute_Correlation'] = (
    correlation_pairs['Correlation'].abs()
)

strong_correlations = (
    correlation_pairs
    .sort_values(
        by='Absolute_Correlation',
        ascending=False
    )
)

display(strong_correlations.head(15))
# Out:
#                   Variable_1               Variable_2  Correlation  \
# 157                 JobLevel            MonthlyIncome         0.95
# 164                 JobLevel        TotalWorkingYears         0.78
# 272           YearsAtCompany     YearsWithCurrManager         0.77
# 191            MonthlyIncome        TotalWorkingYears         0.77
# 221        PercentSalaryHike        PerformanceRating         0.77
# 270           YearsAtCompany       YearsInCurrentRole         0.76
# 274       YearsInCurrentRole     YearsWithCurrManager         0.71
# 16                       Age        TotalWorkingYears         0.68
# 257        TotalWorkingYears           YearsAtCompany         0.63
# 271           YearsAtCompany  YearsSinceLastPromotion         0.62
# 273       YearsInCurrentRole  YearsSinceLastPromotion         0.55
# 167                 JobLevel           YearsAtCompany         0.53
# 275  YearsSinceLastPromotion     YearsWithCurrManager         0.51
# ...

# %%
strong_correlations_filtered = (
    strong_correlations[
        strong_correlations['Absolute_Correlation'] >= 0.30
    ]
)

display(strong_correlations_filtered)
# Out:
#                   Variable_1               Variable_2  Correlation  \
# 157                 JobLevel            MonthlyIncome         0.95
# 164                 JobLevel        TotalWorkingYears         0.78
# 272           YearsAtCompany     YearsWithCurrManager         0.77
# 191            MonthlyIncome        TotalWorkingYears         0.77
# 221        PercentSalaryHike        PerformanceRating         0.77
# 270           YearsAtCompany       YearsInCurrentRole         0.76
# 274       YearsInCurrentRole     YearsWithCurrManager         0.71
# 16                       Age        TotalWorkingYears         0.68
# 257        TotalWorkingYears           YearsAtCompany         0.63
# 271           YearsAtCompany  YearsSinceLastPromotion         0.62
# 273       YearsInCurrentRole  YearsSinceLastPromotion         0.55
# 167                 JobLevel           YearsAtCompany         0.53
# 275  YearsSinceLastPromotion     YearsWithCurrManager         0.51
# ...

# %% [markdown]
# ### key business insights

# %%
overall_attrition_rate = round(
    df['Attrition'].mean() * 100,
    2
)

print("Overall Attrition Rate:", overall_attrition_rate, "%")
# Out:
# Overall Attrition Rate: 16.12 %

# %%
highest_department = department_attrition.loc[
    department_attrition['Attrition_Rate (%)'].idxmax()
]

print(highest_department)
# Out:
# Department            Sales
# Total_Employees         446
# Employees_Left           92
# Attrition_Rate (%)    20.63
# Name: 2, dtype: object

# %%
highest_job_role = job_role_attrition.loc[
    job_role_attrition['Attrition_Rate (%)'].idxmax()
]

print(highest_job_role)
# Out:
# JobRole               Sales Representative
# Total_Employees                         83
# Employees_Left                          33
# Attrition_Rate (%)                   39.76
# Name: 8, dtype: object

# %%
highest_job_level = job_level_attrition.loc[
    job_level_attrition['Attrition_Rate (%)'].idxmax()
]

print(highest_job_level)
# Out:
# JobLevel                1.00
# Total_Employees       543.00
# Employees_Left        143.00
# Attrition_Rate (%)     26.34
# Name: 0, dtype: float64

# %%
largest_promotion_gap = promotion_gap_summary.loc[
    promotion_gap_summary['Employee_Count'].idxmax()
]

print(largest_promotion_gap)
# Out:
# PromotionGapGroup    0-1 Years
# Employee_Count             938
# Percentage               63.81
# Name: 0, dtype: object

# %%
largest_role_duration = role_stagnation_summary.loc[
    role_stagnation_summary['Employee_Count'].idxmax()
]

print(largest_role_duration)
# Out:
# RoleDurationGroup    0-2 Years
# Employee_Count             673
# Percentage               45.78
# Name: 0, dtype: object

# %%
highest_promotion_gap_attrition = promotion_attrition.loc[
    promotion_attrition['Attrition_Rate (%)'].idxmax()
]

print(highest_promotion_gap_attrition)
# Out:
# PromotionGapGroup     2-3 Years
# Total_Employees             211
# Employees_Left               36
# Attrition_Rate (%)        17.06
# Name: 1, dtype: object

# %%
highest_role_duration_attrition = role_duration_attrition.loc[
    role_duration_attrition['Attrition_Rate (%)'].idxmax()
]

print(highest_role_duration_attrition)
# Out:
# RoleDurationGroup     0-2 Years
# Total_Employees             673
# Employees_Left              152
# Attrition_Rate (%)        22.59
# Name: 0, dtype: object

# %%
highest_income_department = department_summary.loc[
    department_summary['Average_Monthly_Income'].idxmax()
]

print(highest_income_department)
# Out:
# Department                              Sales
# Total_Employees                           446
# Employees_Left                             92
# Average_Monthly_Income                6959.17
# Average_Job_Satisfaction                 2.75
# Average_WorkLife_Balance                 2.82
# Average_Training                         2.85
# Average_Years_Since_Last_Promotion       2.35
# Average_Years_In_Current_Role            4.49
# Attrition_Rate (%)                      20.63
# Name: 2, dtype: object

# %%
lowest_satisfaction_department = department_summary.loc[
    department_summary['Average_Job_Satisfaction'].idxmin()
]

print(lowest_satisfaction_department)
# Out:
# Department                            Human Resources
# Total_Employees                                    63
# Employees_Left                                     12
# Average_Monthly_Income                        6654.51
# Average_Job_Satisfaction                          2.6
# Average_WorkLife_Balance                         2.92
# Average_Training                                 2.56
# Average_Years_Since_Last_Promotion               1.78
# Average_Years_In_Current_Role                    3.54
# Attrition_Rate (%)                              19.05
# Name: 0, dtype: object

# %%
lowest_worklife_department = department_summary.loc[
    department_summary['Average_WorkLife_Balance'].idxmin()
]

print(lowest_worklife_department)
# Out:
# Department                            Research & Development
# Total_Employees                                          961
# Employees_Left                                           133
# Average_Monthly_Income                               6281.25
# Average_Job_Satisfaction                                2.73
# Average_WorkLife_Balance                                2.73
# Average_Training                                        2.79
# Average_Years_Since_Last_Promotion                      2.14
# Average_Years_In_Current_Role                           4.16
# Attrition_Rate (%)                                     13.84
# Name: 1, dtype: object

# %%
largest_department_promotion_gap = department_summary.loc[
    department_summary[
        'Average_Years_Since_Last_Promotion'
    ].idxmax()
]

print(largest_department_promotion_gap)
# Out:
# Department                              Sales
# Total_Employees                           446
# Employees_Left                             92
# Average_Monthly_Income                6959.17
# Average_Job_Satisfaction                 2.75
# Average_WorkLife_Balance                 2.82
# Average_Training                         2.85
# Average_Years_Since_Last_Promotion       2.35
# Average_Years_In_Current_Role            4.49
# Attrition_Rate (%)                      20.63
# Name: 2, dtype: object

# %%
display(
    strong_correlations_filtered.head(10)
)
# Out:
#              Variable_1               Variable_2  Correlation  \
# 157            JobLevel            MonthlyIncome         0.95
# 164            JobLevel        TotalWorkingYears         0.78
# 272      YearsAtCompany     YearsWithCurrManager         0.77
# 191       MonthlyIncome        TotalWorkingYears         0.77
# 221   PercentSalaryHike        PerformanceRating         0.77
# 270      YearsAtCompany       YearsInCurrentRole         0.76
# 274  YearsInCurrentRole     YearsWithCurrManager         0.71
# 16                  Age        TotalWorkingYears         0.68
# 257   TotalWorkingYears           YearsAtCompany         0.63
# 271      YearsAtCompany  YearsSinceLastPromotion         0.62
#
#      Absolute_Correlation
# 157                  0.95
# 164                  0.78
# 272                  0.77
# 191                  0.77
# 221                  0.77
# 270                  0.76
# 274                  0.71
# 16                   0.68
# 257                  0.63
# ...

# %%
display(
    attrition_correlation_table.head(10)
)
# Out:
#                   Variable  Correlation_With_Attrition  Absolute_Correlation
# 0        TotalWorkingYears                       -0.17                  0.17
# 1                 JobLevel                       -0.17                  0.17
# 2                      Age                       -0.16                  0.16
# 3       YearsInCurrentRole                       -0.16                  0.16
# 4            MonthlyIncome                       -0.16                  0.16
# 5     YearsWithCurrManager                       -0.16                  0.16
# 6         StockOptionLevel                       -0.14                  0.14
# 7           JobInvolvement                       -0.13                  0.13
# 8           YearsAtCompany                       -0.13                  0.13
# 9  EnvironmentSatisfaction                       -0.10                  0.10

# %%
key_business_insights = pd.DataFrame([
    
    {
        'Insight_Area': 'Overall Attrition',
        
        'Key_Insight': (
            f"The organization has an overall attrition rate of "
            f"{overall_attrition_rate}%."
        ),
        
        'Business_Implication': (
            'This provides the baseline for identifying employee groups '
            'with above-average retention risk.'
        )
    },
    
    {
        'Insight_Area': 'Department Attrition',
        
        'Key_Insight': (
            f"{highest_department['Department']} has the highest attrition "
            f"rate at {highest_department['Attrition_Rate (%)']}%."
        ),
        
        'Business_Implication': (
            'This department may require further investigation into the '
            'factors associated with employee turnover.'
        )
    },
    
    {
        'Insight_Area': 'Job Role Attrition',
        
        'Key_Insight': (
            f"{highest_job_role['JobRole']} has the highest attrition rate "
            f"at {highest_job_role['Attrition_Rate (%)']}%."
        ),
        
        'Business_Implication': (
            'This role represents a potential retention risk group.'
        )
    },
    
    {
        'Insight_Area': 'Job Level Attrition',
        
        'Key_Insight': (
            f"Job Level {highest_job_level['JobLevel']} has the highest "
            f"attrition rate at "
            f"{highest_job_level['Attrition_Rate (%)']}%."
        ),
        
        'Business_Implication': (
            'Retention strategies may need to focus on employees at this '
            'career level.'
        )
    },
    
    {
        'Insight_Area': 'Promotion Gap',
        
        'Key_Insight': (
            f"The largest employee group falls within the "
            f"{largest_promotion_gap['PromotionGapGroup']} promotion gap."
        ),
        
        'Business_Implication': (
            'This indicates where the largest concentration of employees '
            'is located in terms of time since promotion.'
        )
    },
    
    {
        'Insight_Area': 'Role Duration',
        
        'Key_Insight': (
            f"The largest employee group has been in the current role for "
            f"{largest_role_duration['RoleDurationGroup']}."
        ),
        
        'Business_Implication': (
            'Employees with longer role durations may require additional '
            'career progression analysis.'
        )
    },
    
    {
        'Insight_Area': 'Promotion Gap vs Attrition',
        
        'Key_Insight': (
            f"The {highest_promotion_gap_attrition['PromotionGapGroup']} "
            f"promotion-gap group has the highest attrition rate at "
            f"{highest_promotion_gap_attrition['Attrition_Rate (%)']}%."
        ),
        
        'Business_Implication': (
            'This indicates an association between this promotion-gap group '
            'and higher employee turnover.'
        )
    },
    
    {
        'Insight_Area': 'Role Duration vs Attrition',
        
        'Key_Insight': (
            f"The {highest_role_duration_attrition['RoleDurationGroup']} "
            f"role-duration group has the highest attrition rate at "
            f"{highest_role_duration_attrition['Attrition_Rate (%)']}%."
        ),
        
        'Business_Implication': (
            'Employees in this role-duration group may represent a priority '
            'area for retention analysis.'
        )
    },
    
    {
        'Insight_Area': 'Department Satisfaction',
        
        'Key_Insight': (
            f"{lowest_satisfaction_department['Department']} has the lowest "
            f"average job satisfaction at "
            f"{lowest_satisfaction_department['Average_Job_Satisfaction']}."
        ),
        
        'Business_Implication': (
            'This department may benefit from further investigation into '
            'employee experience and satisfaction factors.'
        )
    },
    
    {
        'Insight_Area': 'Work-Life Balance',
        
        'Key_Insight': (
            f"{lowest_worklife_department['Department']} has the lowest "
            f"average work-life balance score at "
            f"{lowest_worklife_department['Average_WorkLife_Balance']}."
        ),
        
        'Business_Implication': (
            'Workload, flexibility, and employee wellbeing in this '
            'department may require further investigation.'
        )
    }
])

display(key_business_insights)
# Out:
#                  Insight_Area  \
# 0           Overall Attrition
# 1        Department Attrition
# 2          Job Role Attrition
# 3         Job Level Attrition
# 4               Promotion Gap
# 5               Role Duration
# 6  Promotion Gap vs Attrition
# 7  Role Duration vs Attrition
# 8     Department Satisfaction
# 9           Work-Life Balance
#
#                                          Key_Insight  \
# 0  The organization has an overall attrition rate...
# 1    Sales has the highest attrition rate at 20.63%.
# 2  Sales Representative has the highest attrition...
# 3  Job Level 1.0 has the highest attrition rate a...
# 4  The largest employee group falls within the 0-...
# 5  The largest employee group has been in the cur...
# 6  The 2-3 Years promotion-gap group has the high...
# 7  The 0-2 Years role-duration group has the high...
# 8  Human Resources has the lowest average job sat...
# 9  Research & Development has the lowest average ...
#
# ...
